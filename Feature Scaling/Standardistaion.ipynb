# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Social_Network_Ads.csv")

# %%
df
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
df = df.iloc[:,2:]

# %%
df
# Out:
#      Age  EstimatedSalary  Purchased
# 0     19            19000          0
# 1     35            20000          0
# 2     26            43000          0
# 3     27            57000          0
# 4     19            76000          0
# ..   ...              ...        ...
# 395   46            41000          1
# 396   51            23000          1
# 397   50            20000          1
# 398   36            33000          0
# 399   49            36000          1
#
# [400 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(df.drop("Purchased", axis = 1),df["Purchased"], test_size=0.2, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train_scaler = scaler.fit_transform(X_train)

# %%
X_test_scale = scaler.transform(X_test)

# %%
X_train_scaler = pd.DataFrame(X_train_scaler,columns=X_train.columns)

# %%
X_test_scaler = pd.DataFrame(X_test_scale,columns=X_test.columns)

# %%
X_train_scaler
# Out:
#           Age  EstimatedSalary
# 0    1.922950         2.146016
# 1    2.020161         0.378719
# 2   -1.382215        -0.432499
# 3   -1.187794        -1.011940
# 4    1.922950        -0.925024
# ..        ...              ...
# 315  0.950843        -1.156800
# 316 -0.896162        -0.780164
# 317 -0.215686        -0.519415
# 318 -1.090583        -0.461471
# 319 -1.187794         1.392742
#
# [320 rows x 2 columns]

# %%
X_test_scaler
# Out:
#          Age  EstimatedSalary
# 0  -0.798951         0.494608
# 1  -0.021265        -0.577359
# 2  -0.312897         0.146943
# 3  -0.798951         0.262831
# 4  -0.312897        -0.577359
# ..       ...              ...
# 75 -1.965480         0.349747
# 76  0.367578         0.262831
# 77  0.173157        -0.287638
# 78  1.436896        -1.040912
# 79  0.853632         1.074049
#
# [80 rows x 2 columns]

# %%
np.round(X_train.describe())
# Out:
#          Age  EstimatedSalary
# count  320.0            320.0
# mean    38.0          69928.0
# std     10.0          34570.0
# min     18.0          15000.0
# 25%     30.0          43000.0
# 50%     38.0          69500.0
# 75%     46.0          88000.0
# max     60.0         150000.0

# %%
np.round(X_train_scaler.describe())
# Out:
#          Age  EstimatedSalary
# count  320.0            320.0
# mean     0.0              0.0
# std      1.0              1.0
# min     -2.0             -2.0
# 25%     -1.0             -1.0
# 50%     -0.0             -0.0
# 75%      1.0              1.0
# max      2.0              2.0

# %%
plt.figure(figsize=(10,7))

plt.subplot(1,2,1)
plt.scatter(x = X_train["Age"], y = X_train["EstimatedSalary"])
plt.title("before")


plt.subplot(1,2,2)
plt.scatter(x = X_train_scaler["Age"], y = X_train_scaler["EstimatedSalary"])
plt.title("after")

plt.show()

# %%
plt.figure(figsize=(10,7))

plt.subplot(1,2,1)
sns.kdeplot(X_train["Age"])
sns.kdeplot(X_train["EstimatedSalary"])
plt.title("before")
plt.legend()

plt.subplot(1,2,2)
sns.kdeplot(X_train_scaler["Age"])
sns.kdeplot(X_train_scaler["EstimatedSalary"])
plt.title("after")
plt.legend()

plt.show()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
